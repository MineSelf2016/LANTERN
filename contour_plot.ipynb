# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function to create data points
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate grid points
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Create contour plot
plt.figure()
cp = plt.contour(X, Y, Z)
plt.clabel(cp, inline=True, fontsize=10)
plt.title('Contour Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data: replace with your actual hyperparameter tuning results
learning_rate = np.linspace(0.001, 0.1, 10)
batch_size = np.linspace(16, 128, 10)
X, Y = np.meshgrid(learning_rate, batch_size)
Z = np.random.randn(10, 10)  # Replace with actual performance metric, e.g., accuracy

# Create contour plot
plt.figure()
cp = plt.contour(X, Y, Z, levels=10)
plt.clabel(cp, inline=True, fontsize=10)
plt.title('Hyperparameter Tuning: Accuracy')
plt.xlabel('Learning Rate')
plt.ylabel('Batch Size')
plt.colorbar(cp, label='Accuracy')
plt.show()
